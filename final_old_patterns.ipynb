# %%
import json


import pandas as pd


#transactions_final

with open('transactions_final.json') as f:
    transactions = json.load(f)

list_trans_id = []

dict_transactions = {}

for key, transaction in transactions['transactions'].items():
    list_trans_id.append(key)
    for k, v in transaction.items():
        if not dict_transactions.get(k):
            dict_transactions[k] = []
            dict_transactions[k].append(v)
        else:
            dict_transactions[k].append(v)

dict_transactions['transaction_id'] = list_trans_id

# %%
df = pd.DataFrame(dict_transactions) # data frame для нового паттерна
df.head(4)
# Out:
#                   date                  card     account account_valid_to  \
# 0  2020-05-04T00:00:04  50785425162189603667  7456771640       2026-03-06
# 1  2020-05-04T00:01:19  57642678631657633216  7456771641       2025-08-15
# 2  2020-05-04T00:02:51  50606101490380719590  7456771642       2034-09-08
# 3  2020-05-04T00:04:16  40801177229019601602  7456771643       2033-12-14
#
#     client last_name first_name patronymic date_of_birth    passport  \
# 0  6-33721   Кадимов  Корнелиус   Ковалько    1993-09-17  2300733597
# 1  6-33721   Кадимов  Корнелиус   Ковалько    1993-09-17  2300733597
# 2  2-10067    Котков   Валерьян   Байбаков    1946-09-08  3153290165
# 3  7-17459  Сафьянов    Кондрат   Романцов    1965-11-27  3307023178
#
#   passport_valid_to         phone oper_type    amount oper_result  terminal  \
# 0        2027-12-11  +74304126656    Оплата   6734.10     Успешно  POS43792
# 1        2021-10-19  +74304126656    Снятие  69108.86       Отказ  POS43792
# ...

# %%
# недействительный аккаунт
a = df[df['date'] > df['account_valid_to']]['transaction_id'].tolist()

#f = open('invalid_account_ids.txt','w')
#for id_oper in a:
#    f.write(id_oper)
#    f.write(', ')
a = df[df['date'] > df['account_valid_to']]
a.head(4)
# Out:
#                    date                  card     account account_valid_to  \
# 25  2020-05-04T00:35:17  54351853040815910412  7456771665       2005-10-15
# 26  2020-05-04T00:36:36  44930928660709788418  7456771666       2015-03-03
# 27  2020-05-04T00:37:43  51419816135305384739  7456771667       2014-08-29
# 75  2020-05-04T01:43:30  57270415368961360823  7456771715       2012-11-05
#
#      client last_name first_name    patronymic date_of_birth    passport  \
# 25  5-01815  Данчиков  Элджернон  Подопрыгоров    1990-06-12  8870665843
# 26  5-01815  Данчиков  Элджернон  Подопрыгоров    1990-06-12  8870665843
# 27  5-01815  Данчиков  Элджернон  Подопрыгоров    1990-06-12  8870665843
# 75  2-34029  Китайчик       Абид    Островсков    1966-01-25  3872751164
#
#    passport_valid_to         phone   oper_type    amount oper_result  \
# 25        2025-11-13  +78082044739      Оплата  89350.59     Успешно
# 26        2033-07-11  +78082044739      Снятие  64978.40     Успешно
# ...

# %%
#недействительный паспорт
b = df[df['date'] > df['passport_valid_to']]['transaction_id'].tolist()

#f = open('invalid_passport_ids.txt','w')
#for id_oper in b:
#    f.write(id_oper)
#    f.write(', ')
b = df[df['date'] > df['passport_valid_to']]
b.head(4)
# Out:
#                     date                  card     account account_valid_to  \
# 2    2020-05-04T00:02:51  50606101490380719590  7456771642       2034-09-08
# 28   2020-05-04T00:38:57  56429703831426013992  7456771668       2027-01-15
# 119  2020-05-04T02:45:04  47504294912053871603  7456771759       2034-10-19
# 120  2020-05-04T02:46:15  54142362437559523627  7456771760       2030-07-12
#
#       client  last_name first_name patronymic date_of_birth    passport  \
# 2    2-10067     Котков   Валерьян   Байбаков    1946-09-08  3153290165
# 28   6-28309   Резвяков    Авирмэд  Данильчев    1995-03-11  3256468165
# 119  8-68970  Скоблилов       Зеэв   Безрукий    1980-11-26  9877664661
# 120  8-68970  Скоблилов       Зеэв   Безрукий    1980-11-26  9877664661
#
